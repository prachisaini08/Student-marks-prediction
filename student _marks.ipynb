# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
import pickle

# %%
df= pd.read_csv("student_marks.csv")
print(df.head())
# Out:
#    Hours  Marks
# 0      1     20
# 1      2     30
# 2      3     40
# 3      4     50
# 4      5     60

# %%
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   10 non-null     int64
#  1   Marks   10 non-null     int64
# dtypes: int64(2)
# memory usage: 292.0 bytes
# None
#           Hours      Marks
# count  10.00000   10.00000
# mean    5.50000   63.50000
# std     3.02765   28.09211
# min     1.00000   20.00000
# 25%     3.25000   42.50000
# 50%     5.50000   65.00000
# 75%     7.75000   87.50000
# max    10.00000  100.00000
# Hours    0
# Marks    0
# dtype: int64

# %%
x=df[['Hours']]
y=df['Marks']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size =0.2,random_state =42)

# %%
lr= LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model =LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model =LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
y_pred =lr.predict(x_test)
print(y_pred)
# Out:
# [96.03448276 31.46551724]

# %%
prediction =model.predict([[6.5]])
print("Predicted Marks: ",prediction[0])
# Out:
# Predicted Marks:  72.74242424242425
# c:\Users\prach\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
print("R2 score :",r2_score(y_test,y_pred))
print("MSE : ",mean_squared_error(y_test,y_pred))
print("mae : ",mean_absolute_error(y_test,y_pred))
# Out:
# R2 score : 0.9984767359229996
# MSE :  1.6089476813317298
# mae :  1.249999999999993

# %%
with open("student_model.pkl","wb")as file:
    pickle.dump(model,file)
    print("model saved successfully")
# Out:
# model saved successfully

# %%
plt.scatter(x,y,color='blue',label='actual data')
plt.plot(x,model.predict(x),color='red',label='Regression Line')
plt.xlabel("Hours studied")
plt.ylabel("marks")
plt.title("Student Marks Prediction")
plt.legend()
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 with open("salary_model.pkl","rb")as file:
#       2     model =pickle.load(file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'salary_model.pkl'
